# %% [markdown]
# # Práctica Guiada de Laboratorio 4 - Inteligencia Artificial G1 (EAPIS) 2022-1

# %% [markdown]
# ### Prof. Rolando A. Maguiña Pérez

# %% [markdown]
# # El Viaje por las ciudades de Andalucía – Búsqueda informada

# %% [markdown]
# ## Introducción

# %% [markdown]
# En la presente práctica, a realizarse el Lunes 06 de Junio del 2022, se abordará el problema denominado “El Viaje por las ciudades de Andalucía” mediante el método informado denominado **búsqueda avara**. Luego de la presentación del problema se pedirá la definición de algunas funciones que se usarán en la implementación del algoritmo del método informado indicado. Enseguida se presentará el código fuente parcial que implementa el algoritmo de dicho método; a partir de dicho código, se plantearán algunas preguntas que los alumnos deberán resolver.

# %% [markdown]
# ## EL VIAJE POR LAS CIUDADES DE ANDALUCÍA

# %% [markdown]
# Supongamos nos encontramos en una capital de la región de España denominada Andalucía (p.e. Sevilla) y deseamos ir a otra capital andaluza (p.e. AlmerÍa). Se sabe que los autobuses sólo van de cada capital a sus vecinas. Enseguida se muestra un mapa de dicha región y las coordenadas geográficas de las ciudades que pertenecen a ella:

# %%
from IPython.display import Image
i = Image(filename='D:\\Cursos\\IA\\Python\\2021-1\\andalucia-distancias.png')
i

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Defina una función de evaluación ad hoc para resolver el problema mediante el método de búsqueda indicado. Asimismo, defina una función en Python llamada *heuristica* que implemente dicha función de evaluación. (3 puntos)
#
# Previamente, con la finalidad de que se usen en la definición de *heuristica*, se presenta el código para almacenar las ciudades y sus coordenadas en un diccionario, luego para extraer las coordenadas y usarlas en la definición de la función *distancia*.

# %% [markdown]
# ### Almacenamiento de coordenadas de ciudades

# %% [markdown]
# Usaremos un diccionario para almacenar la información sobre las coordenadas de c/u de las ciudades.

# %%
ciudades = {"almeria": [409.5,93], "granada":[309,127.5], "malaga":[232.5,75], "cadiz":[63,57], "huelva":[3,139.5], "sevilla":[90,153], "cordoba":[198,207], "jaen":[295.5,192]}
print(ciudades)
# Out:
# {'almeria': [409.5, 93], 'granada': [309, 127.5], 'malaga': [232.5, 75], 'cadiz': [63, 57], 'huelva': [3, 139.5], 'sevilla': [90, 153], 'cordoba': [198, 207], 'jaen': [295.5, 192]}

# %% [markdown]
# ### Definición de función *distancia*

# %% [markdown]
# Definimos una función 'distancia' que, dadas dos ciudades, devuelve la distancia Euclidiana entre ellas. Usa las coordenadas (abcisa,ordenada) de las ciudades en dicho cálculo; las coordenadas se obtienen aplicando el método get(keyN) al diccionario 'ciudades', donde N={1,2} corresponden a la ciudad 1 ó 2.

# %%
import math

# %%
def distancia(key1,key2):
    abcisa1,ordenada1 = ciudades.get(key1)
    abcisa2,ordenada2 = ciudades.get(key2)
    return math.sqrt((abcisa1 - abcisa2)**2 + (ordenada1 - ordenada2)**2)

# %%
distancia('almeria','granada')
# Out:
# 106.25676449054902

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Escriba la(s) función(es) que permitan obtener los sucesores de un nodo cualquiera, **y sus respectivos valores de evaluación**.  			(4 puntos)
#
# Sugerencia: puede usar un diccionario o una lista de listas para almacenar los sucesores con su respectivo valor de evaluación.

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Implemente ahora, a partir del código disponible aunque incompleto mostrado en la celda sgte, el algoritmo de la estrategia de búsqueda avara para resolver el problema (determinar una ruta Sevilla-Almería).
#
# Con esa finalidad efectúe las modificaciones necesarias al código (definiendo funciones e insertándolas, eliminando algunas líneas de código, modificando el código innecesario) a fin de implementar el algoritmo de dicho método. Use para tal efecto las funciones que definió para la resolución de los ejercicios anteriores y las funciones  por definir *nuevossucesores()* y *ordenaporheuristica()*. Enseguida aplique el algoritmo para resolver el problema.  (7 puntos)

# %%
def busquedaavara():
    LE = [estadoinicial]
    LV = []
    # actual = estadoinicial
    nuevossucesores = []
    while LE != []:
        actual = LE.pop[0]
        if actual==estadometa:
            return actual
        else:
            LV.append(actual)         
            nuevossucesores(actual)
            LE.extend(nuevossucesores)
            ordenaporheuristica(LE)

# %% [markdown]
# Nota: *nuevossucesores()* y *ordenaporheuristica()* son funciones a definir; la segunda, ordena de forma ascendente los elementos de una lista.

# %%
def nuevossucesores(actual,abiertos,cerrados):
    cerrados = cerrados.append(actual)
    abiertos =

# %%
def ordenaporheuristica(listanodos)

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# El enfoque utilizado para resolver el problema *Viaje por las ciudades de Andalucía* ha considerado la programación estructurada. Aplique ahora programación orientada a objetos con Python para resolver la pregunta 3, presentando las líneas de código corresspondientes. (6 puntos)

# %% [markdown]
# ### Instrucciones para el envío de la solución

# %% [markdown]
# La solución de la "Práctica Guiada de Laboratorio 4 - IA 2022-1 G1 EAPIS" podrá enviarse como respuesta a la tarea del mismo nombre publicada en la clase de Classroom, hasta las 23:59 h del Miércoles 08 de Junio del 2022, en un archivo con extensión .ipynb.
#
# El documento deberá tener las sgtes características:
#
# Nombre del archivo: solPGL4_IA_G1_nombre-apellidos.ipynb.
#
# Todas las preguntas de la Práctica deben responderse en este mismo cuaderno computacional; la solución a cada pregunta debe registrarse en una celda debajo del plnteamiento de la misma, mencionando explícitamente como subtítulo: "Solución del ejercicio n", donde "n" corresponde al número del ejercicio.
